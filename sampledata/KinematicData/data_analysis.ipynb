# %%
import pandas as pd
import numpy as np
import pingouin

# function to highlight significant p-values
# signficance after Bonferroni Correction is set to p-val < 0.05/23 => 0.002
def highlight_pval(val):
    color = 'yellow' if val < 0.002 else ''
    return f'background-color: {color}'

# %%
# DBS DATASET

# loading DBS on and off dataframes 
dbs_df = pd.read_excel("DBS_Sample_Data.xlsx")
dbs_off_df = dbs_df[dbs_df['Condition DBS'].str.contains('off', case=False, na=False)]
dbs_on_df = dbs_df[dbs_df['Condition DBS'].str.contains('on', case=False, na=False)]

features = list(dbs_df.columns)[3:]

# paired t-test  and statistics for each kinematic feature
dbs_results = pd.DataFrame(columns=['meanON', 'sdON', 'meanOFF', 'sdOFF','T-val','p-val'])
for f in features:
    off = np.array(dbs_off_df[f])
    on = np.array(dbs_on_df[f])
    
    ttest_result = pingouin.ttest(on, off, paired=True)
    
    dbs_results.loc[f] = [round(np.mean(on), 5),
                      round(np.std(on), 5),
                      round(np.mean(off), 5),
                      round(np.std(off), 5),
                      round(ttest_result['T'][0],5), 
                      round(ttest_result['p-val'][0],5)]

dbs_results.style.applymap(highlight_pval, subset=['p-val']).format(precision=5)
# Out:
# <style type="text/css">
# #T_79ee0_row0_col5, #T_79ee0_row1_col5, #T_79ee0_row2_col5, #T_79ee0_row3_col5, #T_79ee0_row4_col5, #T_79ee0_row5_col5, #T_79ee0_row6_col5, #T_79ee0_row7_col5, #T_79ee0_row8_col5, #T_79ee0_row9_col5, #T_79ee0_row10_col5, #T_79ee0_row11_col5, #T_79ee0_row12_col5, #T_79ee0_row13_col5, #T_79ee0_row14_col5, #T_79ee0_row15_col5, #T_79ee0_row16_col5, #T_79ee0_row18_col5, #T_79ee0_row22_col5 {
#   background-color: ;
# }
# #T_79ee0_row17_col5, #T_79ee0_row19_col5, #T_79ee0_row20_col5, #T_79ee0_row21_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_79ee0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79ee0_level0_col0" class="col_heading level0 col0" >meanON</th>
#       <th id="T_79ee0_level0_col1" class="col_heading level0 col1" >sdON</th>
#       <th id="T_79ee0_level0_col2" class="col_heading level0 col2" >meanOFF</th>
#       <th id="T_79ee0_level0_col3" class="col_heading level0 col3" >sdOFF</th>
#       <th id="T_79ee0_level0_col4" class="col_heading level0 col4" >T-val</th>
#       <th id="T_79ee0_level0_col5" class="col_heading level0 col5" >p-val</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79ee0_level0_row0" class="row_heading level0 row0" >MeanAmplitude</th>
#       <td id="T_79ee0_row0_col0" class="data row0 col0" >0.53313</td>
#       <td id="T_79ee0_row0_col1" class="data row0 col1" >0.18151</td>
#       <td id="T_79ee0_row0_col2" class="data row0 col2" >0.41742</td>
#       <td id="T_79ee0_row0_col3" class="data row0 col3" >0.15969</td>
#       <td id="T_79ee0_row0_col4" class="data row0 col4" >3.07417</td>
#       <td id="T_79ee0_row0_col5" class="data row0 col5" >0.00537</td>
#     </tr>
#     <tr>
#       <th id="T_79ee0_level0_row1" class="row_heading level0 row1" >StdAmplitude</th>
#       <td id="T_79ee0_row1_col0" class="data row1 col0" >0.07816</td>
#       <td id="T_79ee0_row1_col1" class="data row1 col1" >0.03126</td>
#       <td id="T_79ee0_row1_col2" class="data row1 col2" >0.09436</td>
#       <td id="T_79ee0_row1_col3" class="data row1 col3" >0.02732</td>
#       <td id="T_79ee0_row1_col4" class="data row1 col4" >-2.42754</td>
#       <td id="T_79ee0_row1_col5" class="data row1 col5" >0.02344</td>
#     </tr>
#     <tr>
#       <th id="T_79ee0_level0_row2" class="row_heading level0 row2" >MeanSpeed</th>
#       <td id="T_79ee0_row2_col0" class="data row2 col0" >1.19266</td>
#       <td id="T_79ee0_row2_col1" class="data row2 col1" >0.50456</td>
#       <td id="T_79ee0_row2_col2" class="data row2 col2" >1.03857</td>
#       <td id="T_79ee0_row2_col3" class="data row2 col3" >0.58575</td>
#       <td id="T_79ee0_row2_col4" class="data row2 col4" >1.35116</td>
#       <td id="T_79ee0_row2_col5" class="data row2 col5" >0.18979</td>
#     </tr>
#     <tr>
#       <th id="T_79ee0_level0_row3" class="row_heading level0 row3" >StdSpeed</th>
#       <td id="T_79ee0_row3_col0" class="data row3 col0" >0.20002</td>
#       <td id="T_79ee0_row3_col1" class="data row3 col1" >0.11716</td>
#       <td id="T_79ee0_row3_col2" class="data row3 col2" >0.22934</td>
#       <td id="T_79ee0_row3_col3" class="data row3 col3" >0.12912</td>
#       <td id="T_79ee0_row3_col4" class="data row3 col4" >-1.01303</td>
#       <td id="T_79ee0_row3_col5" class="data row3 col5" >0.32158</td>
#     </tr>
#     <tr>
#       <th id="T_79ee0_level0_row4" class="row_heading level0 row4" >MeanRMSVelocity</th>
#       <td id="T_79ee0_row4_col0" class="data row4 col0" >3.06567</td>
#       <td id="T_79ee0_row4_col1" class="data row4 col1" >1.20794</td>
#       <td id="T_79ee0_row4_col2" class="data row4 col2" >2.64174</td>
#       <td id="T_79ee0_row4_col3" class="data row4 col3" >1.42243</td>
#       <td id="T_79ee0_row4_col4" class="data row4 col4" >1.56406</td>
#       <td id="T_79ee0_row4_col5" class="data row4 col5" >0.13146</td>
#     </tr>
#     <tr>
#       <th id="T_79ee0_level0_row5" class="row_heading level0 row5" >StdRMSVelocity</th>
#       <td id="T_79ee0_row5_col0" class="data row5 col0" >0.48779</td>
#       <td id="T_79ee0_row5_col1" class="data row5 col1" >0.25691</td>
#       <td id="T_79ee0_row5_col2" class="data row5 col2" >0.55405</td>
#       <td id="T_79ee0_row5_col3" class="data row5 col3" >0.30672</td>
#       <td id="T_79ee0_row5_col4" class="data row5 col4" >-0.95697</td>
#       <td id="T_79ee0_row5_col5" class="data row5 col5" >0.34853</td>
#     </tr>
#     <tr>
#       <th id="T_79ee0_level0_row6" class="row_heading level0 row6" >MeanOpeningSpeed</th>
#       <td id="T_79ee0_row6_col0" class="data row6 col0" >2.25970</td>
#       <td id="T_79ee0_row6_col1" class="data row6 col1" >1.00170</td>
#       <td id="T_79ee0_row6_col2" class="data row6 col2" >2.07612</td>
#       <td id="T_79ee0_row6_col3" class="data row6 col3" >1.19076</td>
#       <td id="T_79ee0_row6_col4" class="data row6 col4" >0.80343</td>
#       <td id="T_79ee0_row6_col5" class="data row6 col5" >0.42995</td>
#     </tr>
#     <tr>
#       <th id="T_79ee0_level0_row7" class="row_heading level0 row7" >stdOpeningSpeed</th>
#       <td id="T_79ee0_row7_col0" class="data row7 col0" >0.41739</td>
#       <td id="T_79ee0_row7_col1" class="data row7 col1" >0.22393</td>
#       <td id="T_79ee0_row7_col2" class="data row7 col2" >0.51667</td>
#       <td id="T_79ee0_row7_col3" class="data row7 col3" >0.26414</td>
#       <td id="T_79ee0_row7_col4" class="data row7 col4" >-1.70446</td>
#       <td id="T_79ee0_row7_col5" class="data row7 col5" >0.10177</td>
#     </tr>
#     <tr>
#       <th id="T_79ee0_level0_row8" class="row_heading level0 row8" >meanClosingSpeed</th>
#       <td id="T_79ee0_row8_col0" class="data row8 col0" >2.66094</td>
#       <td id="T_79ee0_row8_col1" class="data row8 col1" >1.06089</td>
#       <td id="T_79ee0_row8_col2" class="data row8 col2" >2.18948</td>
#       <td id="T_79ee0_row8_col3" class="data row8 col3" >1.16056</td>
#       <td id="T_79ee0_row8_col4" class="data row8 col4" >1.97416</td>
#       <td id="T_79ee0_row8_col5" class="data row8 col5" >0.06049</td>
#     </tr>
#     <tr>
#       <th id="T_79ee0_level0_row9" class="row_heading level0 row9" >stdClosingSpeed</th>
#       <td id="T_79ee0_row9_col0" class="data row9 col0" >0.54190</td>
#       <td id="T_79ee0_row9_col1" class="data row9 col1" >0.24245</td>
#       <td id="T_79ee0_row9_col2" class="data row9 col2" >0.56836</td>
#       <td id="T_79ee0_row9_col3" class="data row9 col3" >0.27432</td>
#       <td id="T_79ee0_row9_col4" class="data row9 col4" >-0.44210</td>
#       <td id="T_79ee0_row9_col5" class="data row9 col5" >0.66255</td>
#     </tr>
#     <tr>
#       <th id="T_79ee0_level0_row10" class="row_heading level0 row10" >meanCycleDuration</th>
#       <td id="T_79ee0_row10_col0" class="data row10 col0" >0.50650</td>
#       <td id="T_79ee0_row10_col1" class="data row10 col1" >0.21671</td>
#       <td id="T_79ee0_row10_col2" class="data row10 col2" >0.47837</td>
#       <td id="T_79ee0_row10_col3" class="data row10 col3" >0.19872</td>
#       <td id="T_79ee0_row10_col4" class="data row10 col4" >0.51205</td>
#       <td id="T_79ee0_row10_col5" class="data row10 col5" >0.61350</td>
#     </tr>
#     <tr>
#       <th id="T_79ee0_level0_row11" class="row_heading level0 row11" >stdCycleDuration</th>
#       <td id="T_79ee0_row11_col0" class="data row11 col0" >0.06228</td>
#       <td id="T_79ee0_row11_col1" class="data row11 col1" >0.03778</td>
#       <td id="T_79ee0_row11_col2" class="data row11 col2" >0.07609</td>
#       <td id="T_79ee0_row11_col3" class="data row11 col3" >0.05454</td>
#       <td id="T_79ee0_row11_col4" class="data row11 col4" >-1.26925</td>
#       <td id="T_79ee0_row11_col5" class="data row11 col5" >0.21705</td>
#     </tr>
#     <tr>
#       <th id="T_79ee0_level0_row12" class="row_heading level0 row12" >rangeCycleDuration</th>
#       <td id="T_79ee0_row12_col0" class="data row12 col0" >0.23959</td>
#       <td id="T_79ee0_row12_col1" class="data row12 col1" >0.18320</td>
#       <td id="T_79ee0_row12_col2" class="data row12 col2" >0.36748</td>
#       <td id="T_79ee0_row12_col3" class="data row12 col3" >0.35281</td>
#       <td id="T_79ee0_row12_col4" class="data row12 col4" >-1.56759</td>
#       <td id="T_79ee0_row12

# %%
# MED DATASET

# loading MED on and off dataframes 
med_df = pd.read_excel("MED_Sample_Data.xlsx")
med_off_df = med_df[med_df['Condition MED'].str.contains('off', case=False, na=False)]
med_on_df = med_df[med_df['Condition MED'].str.contains('on', case=False, na=False)]

features = list(med_df.columns)[3:]

# paired t-test  and statistics for each kinematic feature
med_results = pd.DataFrame(columns=['meanON', 'sdON', 'meanOFF', 'sdOFF','T-val','p-val'])
for f in features:
    off = np.array(med_off_df[f])
    on = np.array(med_on_df[f])
    
    ttest_result = pingouin.ttest(on, off, paired=True)
    
    med_results.loc[f] = [round(np.mean(on), 5),
                      round(np.std(on), 5),
                      round(np.mean(off), 5),
                      round(np.std(off), 5),
                      round(ttest_result['T'][0],5), 
                      round(ttest_result['p-val'][0],5)]

med_results.style.applymap(highlight_pval, subset=['p-val']).format(precision=5)
# Out:
# <style type="text/css">
# #T_7b0f9_row0_col5, #T_7b0f9_row1_col5, #T_7b0f9_row3_col5, #T_7b0f9_row5_col5, #T_7b0f9_row7_col5, #T_7b0f9_row8_col5, #T_7b0f9_row9_col5, #T_7b0f9_row10_col5, #T_7b0f9_row11_col5, #T_7b0f9_row12_col5, #T_7b0f9_row13_col5, #T_7b0f9_row14_col5, #T_7b0f9_row15_col5, #T_7b0f9_row16_col5, #T_7b0f9_row17_col5, #T_7b0f9_row18_col5, #T_7b0f9_row19_col5, #T_7b0f9_row20_col5, #T_7b0f9_row21_col5, #T_7b0f9_row22_col5 {
#   background-color: ;
# }
# #T_7b0f9_row2_col5, #T_7b0f9_row4_col5, #T_7b0f9_row6_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_7b0f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b0f9_level0_col0" class="col_heading level0 col0" >meanON</th>
#       <th id="T_7b0f9_level0_col1" class="col_heading level0 col1" >sdON</th>
#       <th id="T_7b0f9_level0_col2" class="col_heading level0 col2" >meanOFF</th>
#       <th id="T_7b0f9_level0_col3" class="col_heading level0 col3" >sdOFF</th>
#       <th id="T_7b0f9_level0_col4" class="col_heading level0 col4" >T-val</th>
#       <th id="T_7b0f9_level0_col5" class="col_heading level0 col5" >p-val</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b0f9_level0_row0" class="row_heading level0 row0" >MeanAmplitude</th>
#       <td id="T_7b0f9_row0_col0" class="data row0 col0" >1.03085</td>
#       <td id="T_7b0f9_row0_col1" class="data row0 col1" >0.34785</td>
#       <td id="T_7b0f9_row0_col2" class="data row0 col2" >1.00989</td>
#       <td id="T_7b0f9_row0_col3" class="data row0 col3" >0.27635</td>
#       <td id="T_7b0f9_row0_col4" class="data row0 col4" >0.33724</td>
#       <td id="T_7b0f9_row0_col5" class="data row0 col5" >0.73913</td>
#     </tr>
#     <tr>
#       <th id="T_7b0f9_level0_row1" class="row_heading level0 row1" >StdAmplitude</th>
#       <td id="T_7b0f9_row1_col0" class="data row1 col0" >0.15672</td>
#       <td id="T_7b0f9_row1_col1" class="data row1 col1" >0.08847</td>
#       <td id="T_7b0f9_row1_col2" class="data row1 col2" >0.15248</td>
#       <td id="T_7b0f9_row1_col3" class="data row1 col3" >0.07241</td>
#       <td id="T_7b0f9_row1_col4" class="data row1 col4" >0.27117</td>
#       <td id="T_7b0f9_row1_col5" class="data row1 col5" >0.78879</td>
#     </tr>
#     <tr>
#       <th id="T_7b0f9_level0_row2" class="row_heading level0 row2" >MeanSpeed</th>
#       <td id="T_7b0f9_row2_col0" class="data row2 col0" >2.66597</td>
#       <td id="T_7b0f9_row2_col1" class="data row2 col1" >1.14191</td>
#       <td id="T_7b0f9_row2_col2" class="data row2 col2" >2.01149</td>
#       <td id="T_7b0f9_row2_col3" class="data row2 col3" >1.05255</td>
#       <td id="T_7b0f9_row2_col4" class="data row2 col4" >3.58411</td>
#       <td id="T_7b0f9_row2_col5" class="data row2 col5" >0.00165</td>
#     </tr>
#     <tr>
#       <th id="T_7b0f9_level0_row3" class="row_heading level0 row3" >StdSpeed</th>
#       <td id="T_7b0f9_row3_col0" class="data row3 col0" >0.34639</td>
#       <td id="T_7b0f9_row3_col1" class="data row3 col1" >0.14555</td>
#       <td id="T_7b0f9_row3_col2" class="data row3 col2" >0.33123</td>
#       <td id="T_7b0f9_row3_col3" class="data row3 col3" >0.16522</td>
#       <td id="T_7b0f9_row3_col4" class="data row3 col4" >0.40663</td>
#       <td id="T_7b0f9_row3_col5" class="data row3 col5" >0.68821</td>
#     </tr>
#     <tr>
#       <th id="T_7b0f9_level0_row4" class="row_heading level0 row4" >MeanRMSVelocity</th>
#       <td id="T_7b0f9_row4_col0" class="data row4 col0" >6.51222</td>
#       <td id="T_7b0f9_row4_col1" class="data row4 col1" >2.56472</td>
#       <td id="T_7b0f9_row4_col2" class="data row4 col2" >5.03935</td>
#       <td id="T_7b0f9_row4_col3" class="data row4 col3" >2.37523</td>
#       <td id="T_7b0f9_row4_col4" class="data row4 col4" >3.51466</td>
#       <td id="T_7b0f9_row4_col5" class="data row4 col5" >0.00195</td>
#     </tr>
#     <tr>
#       <th id="T_7b0f9_level0_row5" class="row_heading level0 row5" >StdRMSVelocity</th>
#       <td id="T_7b0f9_row5_col0" class="data row5 col0" >0.79840</td>
#       <td id="T_7b0f9_row5_col1" class="data row5 col1" >0.34311</td>
#       <td id="T_7b0f9_row5_col2" class="data row5 col2" >0.75541</td>
#       <td id="T_7b0f9_row5_col3" class="data row5 col3" >0.34606</td>
#       <td id="T_7b0f9_row5_col4" class="data row5 col4" >0.54248</td>
#       <td id="T_7b0f9_row5_col5" class="data row5 col5" >0.59294</td>
#     </tr>
#     <tr>
#       <th id="T_7b0f9_level0_row6" class="row_heading level0 row6" >MeanOpeningSpeed</th>
#       <td id="T_7b0f9_row6_col0" class="data row6 col0" >5.06356</td>
#       <td id="T_7b0f9_row6_col1" class="data row6 col1" >2.28120</td>
#       <td id="T_7b0f9_row6_col2" class="data row6 col2" >3.76201</td>
#       <td id="T_7b0f9_row6_col3" class="data row6 col3" >2.09970</td>
#       <td id="T_7b0f9_row6_col4" class="data row6 col4" >3.55198</td>
#       <td id="T_7b0f9_row6_col5" class="data row6 col5" >0.00179</td>
#     </tr>
#     <tr>
#       <th id="T_7b0f9_level0_row7" class="row_heading level0 row7" >stdOpeningSpeed</th>
#       <td id="T_7b0f9_row7_col0" class="data row7 col0" >0.74294</td>
#       <td id="T_7b0f9_row7_col1" class="data row7 col1" >0.32293</td>
#       <td id="T_7b0f9_row7_col2" class="data row7 col2" >0.73404</td>
#       <td id="T_7b0f9_row7_col3" class="data row7 col3" >0.37385</td>
#       <td id="T_7b0f9_row7_col4" class="data row7 col4" >0.09887</td>
#       <td id="T_7b0f9_row7_col5" class="data row7 col5" >0.92214</td>
#     </tr>
#     <tr>
#       <th id="T_7b0f9_level0_row8" class="row_heading level0 row8" >meanClosingSpeed</th>
#       <td id="T_7b0f9_row8_col0" class="data row8 col0" >5.81236</td>
#       <td id="T_7b0f9_row8_col1" class="data row8 col1" >2.23471</td>
#       <td id="T_7b0f9_row8_col2" class="data row8 col2" >4.54115</td>
#       <td id="T_7b0f9_row8_col3" class="data row8 col3" >2.11385</td>
#       <td id="T_7b0f9_row8_col4" class="data row8 col4" >3.21363</td>
#       <td id="T_7b0f9_row8_col5" class="data row8 col5" >0.00400</td>
#     </tr>
#     <tr>
#       <th id="T_7b0f9_level0_row9" class="row_heading level0 row9" >stdClosingSpeed</th>
#       <td id="T_7b0f9_row9_col0" class="data row9 col0" >0.90316</td>
#       <td id="T_7b0f9_row9_col1" class="data row9 col1" >0.34094</td>
#       <td id="T_7b0f9_row9_col2" class="data row9 col2" >0.88544</td>
#       <td id="T_7b0f9_row9_col3" class="data row9 col3" >0.32709</td>
#       <td id="T_7b0f9_row9_col4" class="data row9 col4" >0.18241</td>
#       <td id="T_7b0f9_row9_col5" class="data row9 col5" >0.85693</td>
#     </tr>
#     <tr>
#       <th id="T_7b0f9_level0_row10" class="row_heading level0 row10" >meanCycleDuration</th>
#       <td id="T_7b0f9_row10_col0" class="data row10 col0" >0.41958</td>
#       <td id="T_7b0f9_row10_col1" class="data row10 col1" >0.17962</td>
#       <td id="T_7b0f9_row10_col2" class="data row10 col2" >0.76946</td>
#       <td id="T_7b0f9_row10_col3" class="data row10 col3" >0.79113</td>
#       <td id="T_7b0f9_row10_col4" class="data row10 col4" >-2.44448</td>
#       <td id="T_7b0f9_row10_col5" class="data row10 col5" >0.02298</td>
#     </tr>
#     <tr>
#       <th id="T_7b0f9_level0_row11" class="row_heading level0 row11" >stdCycleDuration</th>
#       <td id="T_7b0f9_row11_col0" class="data row11 col0" >0.06329</td>
#       <td id="T_7b0f9_row11_col1" class="data row11 col1" >0.07166</td>
#       <td id="T_7b0f9_row11_col2" class="data row11 col2" >0.17549</td>
#       <td id="T_7b0f9_row11_col3" class="data row11 col3" >0.26052</td>
#       <td id="T_7b0f9_row11_col4" class="data row11 col4" >-2.64325</td>
#       <td id="T_7b0f9_row11_col5" class="data row11 col5" >0.01485</td>
#     </tr>
#     <tr>
#       <th id="T_7b0f9_level0_row12" class="row_heading level0 row12" >rangeCycleDuration</th>
#       <td id="T_7b0f9_row12_col0" class="data row12 col0" >0.21232</td>
#       <td id="T_7b0f9_row12_col1" class="data row12 col1" >0.21909</td>
#       <td id="T_7b0f9_row12_col2" class="data row12 col2" >0.31014</td>
#       <td id="T_7b0f9_row12_col3" class="data row12 col3" >0.22665</td>
#       <td id="T_7b0f9_row12_col4" class="data row12 col4" >-1.42519</td>
#       <td id="T_7b0f9_row12_col
